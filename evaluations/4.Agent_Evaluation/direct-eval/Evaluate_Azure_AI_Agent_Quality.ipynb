# %% [markdown]
# # Evaluate AI agents (Azure AI Agent Service) in Azure AI Foundry

# %% [markdown]
# ## Objective
#
#
# This sample demonstrates how to evaluate an AI agent (Azure AI Agent Service) on these important aspects of your agentic workflow:
#
# - Intent Resolution: Measures how well the agent identifies the user’s request, including how well it scopes the user’s intent, asks clarifying questions, and reminds end users of its scope of capabilities.
# - Tool Call Accuracy: Evaluates the agent's ability to select the appropriate tools, and process correct parameters from previous steps.
# - Task Adherence: Measures how well the agent’s response adheres to its assigned tasks, according to its system message and prior steps.
#
# For AI agents outside of Azure AI Agent Service, you can still provide th agent data in the two formats (either simple data or agent messages) specified in the individual evaluator samples:
# - [Intent resolution](https://aka.ms/intentresolution-sample)
# - [Tool call accuracy](https://aka.ms/toolcallaccuracy-sample)
# - [Task adherence](https://aka.ms/taskadherence-sample)
# - [Response Completeness](https://aka.ms/rescompleteness-sample)
#
#
#
# ## Time
#
# You should expect to spend about 20 minutes running this notebook.
#
# ## Before you begin
# Creating an agent using Azure AI agent service requires an Azure AI Foundry project and a deployed, supported model. See more details in [Create a new agent](https://learn.microsoft.com/azure/ai-services/agents/quickstart?pivots=ai-foundry-portal).
#
# For quality evaluation, you need to deploy a `gpt` model supporting JSON mode. We recommend a model `gpt-4o` or `gpt-4o-mini` for their strong reasoning capabilities.
#
# Important: Make sure to authenticate to Azure using `az login` in your terminal before running this notebook.
#
# ### Prerequisite
#
# Before running the sample:
# ```bash
# pip install azure-ai-projects azure-identity azure-ai-evaluation
# ```
# Set these environment variables with your own values:
# 1) **PROJECT_CONNECTION_STRING** - The project connection string, as found in the overview page of your Azure AI Foundry project.
# 2) **MODEL_DEPLOYMENT_NAME** - The deployment name of the model for AI-assisted evaluators, as found under the "Name" column in the "Models + endpoints" tab in your Azure AI Foundry project.
# 3) **AZURE_OPENAI_ENDPOINT** - Azure Open AI Endpoint to be used for evaluation.
# 4) **AZURE_OPENAI_API_KEY** - Azure Open AI Key to be used for evaluation.
# 5) **AZURE_OPENAI_API_VERSION** - Azure Open AI Api version to be used for evaluation.
# 6) **AZURE_SUBSCRIPTION_ID** - Azure Subscription Id of Azure AI Project
# 7) **PROJECT_NAME** - Azure AI Project Name
# 8) **RESOURCE_GROUP_NAME** - Azure AI Project Resource Group Name
# 9) **AGENT_MODEL_DEPLOYMENT_NAME** - The deployment name of the model for your Azure AI agent, as found under the "Name" column in the "Models + endpoints" tab in your Azure AI Foundry project.

# %% [markdown]
# ### Initializing Project Client

# %%
import os
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from azure.ai.projects.models import FunctionTool, ToolSet

# Import your custom functions to be used as Tools for the Agent
from user_functions import user_functions

project_client = AIProjectClient.from_connection_string(
    credential=DefaultAzureCredential(),
    conn_str=os.environ["PROJECT_CONNECTION_STRING"],
)

AGENT_NAME = "Seattle Tourist Assistant"

# Add Tools to be used by Agent
functions = FunctionTool(user_functions)

toolset = ToolSet()
toolset.add(functions)

# To enable tool calls executed automatically
project_client.agents.enable_auto_function_calls(toolset=toolset)

# %% [markdown]
# ### Create an AI agent (Azure AI Agent Service)

# %%
agent = project_client.agents.create_agent(
    model=os.environ["MODEL_DEPLOYMENT_NAME"],
    name=AGENT_NAME,
    instructions="You are a helpful assistant",
    toolset=toolset,
)

print(f"Created agent, ID: {agent.id}")
# Out:
# Created agent, ID: asst_7aFYY9w0hussRhftmXqUHeL7

# %% [markdown]
# ### Create Thread

# %%
thread = project_client.agents.create_thread()
print(f"Created thread, ID: {thread.id}")
# Out:
# Created thread, ID: thread_8MLzpIZzQUgxJbUvlI2JBzh2

# %% [markdown]
# ## Conversation with Agent
# Use below cells to have conversation with the agent
# - `Create Message[1]`
# - `Execute[2]`

# %% [markdown]
# ### Create Message[1]

# %%
# Create message to thread

MESSAGE = "Can you email me weather info for Seattle ?"

message = project_client.agents.create_message(
    thread_id=thread.id,
    role="user",
    content=MESSAGE,
)
print(f"Created message, ID: {message.id}")
# Out:
# Created message, ID: msg_ui3rhUIysNmYWhjxypSvxaJb

# %% [markdown]
# ### Execute[2]

# %%
run = project_client.agents.create_and_process_run(thread_id=thread.id, agent_id=agent.id)

print(f"Run finished with status: {run.status}")

if run.status == "failed":
    print(f"Run failed: {run.last_error}")

print(f"Run ID: {run.id}")
# Out:
# Run finished with status: RunStatus.FAILED
# Run failed: {'code': 'invalid_engine_error', 'message': 'No connection matching model: gpt4o'}
# Run ID: run_efNOVKtAsa6EbxQtClBDjtZo

# %% [markdown]
# ### List Messages

# %%
for message in project_client.agents.list_messages(thread.id, order="asc").data:
    print(f"Role: {message.role}")
    print(f"Content: {message.content[0].text.value}")
    print("-" * 40)
# Out:
# Role: MessageRole.USER
# Content: Can you email me weather info for Seattle ?
# ----------------------------------------

# %% [markdown]
# # Evaluate

# %% [markdown]
# ### Get data from agent

# %%
from azure.ai.evaluation import AIAgentConverter

# Initialize the converter that will be backed by the project.
converter = AIAgentConverter(project_client)

thread_id = thread.id
run_id = run.id
file_name = "evaluation_data.jsonl"

# Get a single agent run data
evaluation_data_single_run = converter.convert(thread_id=thread_id, run_id=run_id)

# Run this to save thread data to a JSONL file for evaluation
# Save the agent thread data to a JSONL file
# evaluation_data = converter.prepare_evaluation_data(thread_ids=thread_id, filename=<>)
# print(json.dumps(evaluation_data, indent=4))

# %% [markdown]
# ### Setting up evaluator
#
# We will select the following evaluators to assess the different aspects relevant for agent quality:
#
# - [Intent resolution](https://aka.ms/intentresolution-sample): measures the extent of which an agent identifies the correct intent from a user query. Scale: integer 1-5. Higher is better.
# - [Tool call accuracy](https://aka.ms/toolcallaccuracy-sample): evaluates the agent’s ability to select the appropriate tools, and process correct parameters from previous steps. Scale: float 0-1. Higher is better.
# - [Task adherence](https://aka.ms/taskadherence-sample): measures the extent of which an agent’s final response adheres to the task based on its system message and a user query. Scale: integer 1-5. Higher is better.

# %%
from azure.ai.evaluation import (
    ToolCallAccuracyEvaluator,
    AzureOpenAIModelConfiguration,
    IntentResolutionEvaluator,
    TaskAdherenceEvaluator,
)
from pprint import pprint

model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    azure_deployment=os.environ["MODEL_DEPLOYMENT_NAME"],
)

intent_resolution = IntentResolutionEvaluator(model_config=model_config)

tool_call_accuracy = ToolCallAccuracyEvaluator(model_config=model_config)

task_adherence = TaskAdherenceEvaluator(model_config=model_config)
# Out:
# WARNING:azure.ai.evaluation._common._experimental:Class IntentResolutionEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# WARNING:azure.ai.evaluation._common._experimental:Class ToolCallAccuracyEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# WARNING:azure.ai.evaluation._common._experimental:Class TaskAdherenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %% [markdown]
# ### Run Evaluator

# %%
from azure.ai.evaluation import evaluate

response = evaluate(
    data=file_name,
    evaluators={
        "tool_call_accuracy": tool_call_accuracy,
        "intent_resolution": intent_resolution,
        "task_adherence": task_adherence,
    },
    azure_ai_project=os.environ.get("AIPROJECT_CONNECTION_STRING"),
)
pprint(f'AI Foundary URL: {response.get("studio_url")}')
# Out:
# 2025-10-21 09:36:19 -0400   38140 execution.bulk     INFO     Finished 1 / 5 lines.
# 2025-10-21 09:36:19 -0400   38140 execution.bulk     INFO     Average execution time for completed lines: 0.2 seconds. Estimated time for incomplete lines: 0.8 seconds.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Finished 1 / 5 lines.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Average execution time for completed lines: 1.0 seconds. Estimated time for incomplete lines: 4.0 seconds.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Finished 2 / 5 lines.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Average execution time for completed lines: 0.54 seconds. Estimated time for incomplete lines: 1.62 seconds.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Finished 3 / 5 lines.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Average execution time for completed lines: 0.39 seconds. Estimated time for incomplete lines: 0.78 seconds.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-10-21 09:36:20 -0400   35700 execution.bulk     INFO     Average execution time for completed lines: 0.25 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Finished 1 / 5 lines.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Average execution time for completed lines: 1.35 seconds. Estimated time for incomplete lines: 5.4 seconds.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Finished 2 / 5 lines.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Average execution time for completed lines: 0.7 seconds. Estimated time for incomplete lines: 2.1 seconds.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Finished 3 / 5 lines.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Average execution time for completed lines: 0.47 seconds. Estimated time for incomplete lines: 0.94 seconds.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Finished 4 / 5 lines.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Average execution time for completed lines: 0.41 seconds. Estimated time for incomplete lines: 0.41 seconds.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-10-21 09:36:21 -0400   30836 execution.bulk     INFO     Average execution time for completed lines: 0.34 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "intent_resolution_20251021_133619_680905"
# Run status: "Completed"
# Start time: "2025-10-21 13:36:19.680905+00:00"
# Duration: "0:00:01.998319"
#
# ======= Run Summary =======
#
# Run name: "task_adherence_20251021_133619_688947"
# Run status: "Completed"
# Start time: "2025-10-21 13:36:19.688947+00:00"
# Duration: "0:00:02.007719"
#
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Finished 2 / 5 lines.
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Average execution time for completed lines: 1.17 seconds. Estimated time for incomplete lines: 3.51 seconds.
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Finished 3 / 5 lines.
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Average execution time for completed lines: 0.83 seconds. Estimated time for incomplete lines: 1.66 seconds.
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Finished 4 / 5 lines.
# 2025-10-21 09:36:22 -0400   38140 execution.bulk     INFO     Average execution time for completed lines: 0.69 seconds. Estimated time for incomplete lines: 0.69 seconds.
# 2025-10-21 09:36:24 -0400   38140 execution.bulk     INFO     Finished 5 / 5 lines.
# 2025-10-21 09:36:24 -0400   38140 execution.bulk     INFO     Average execution time for completed lines: 0.88 seconds. Estimated time for incomplete lines: 0.0 seconds.
# WARNING:run:Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# WARNING:run:Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# WARNING:run:Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "tool_call_accuracy_20251021_133619_680181"
# Run status: "Completed"
# Start time: "2025-10-21 13:36:19.680181+00:00"
# Duration: "0:00:05.066712"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "tool_call_accuracy": {
#         "status": "Completed",
#         "duration": "0:00:05.066712",
#         "completed_lines": 5,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "intent_resolution": {
#         "status": "Completed",
#         "duration": "0:00:01.998319",
#         "completed_lines": 5,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "task_adherence": {
#         "status": "Completed",
#         "duration": "0:00:02.007719",
#         "completed_lines": 5,
#         "failed_lines": 0,
#         "log_path": null
#     }
# }
#
# ====================================================
#
# ('AI Foundary URL: '
#  'https://ai.azure.com/resource/build/evaluation/a7769b5e-2a27-48d3-a06e-b99748e4ada7?wsid=/subscriptions/382e9d43-0c24-4bf6-b807-0a4935bdc6f6/resourceGroups/rg-agashirazi-5194/providers/Microsoft.CognitiveServices/accounts/agashirazi-5194-resource/projects/agashirazi-5194&tid=16b3c013-d300-468d-ac64-7eda0820b6d3')

# %% [markdown]
# ## Inspect results on Azure AI Foundry
#
# Go to AI Foundry URL for rich Azure AI Foundry data visualization to inspect the evaluation scores and reasoning to quickly identify bugs and issues of your agent to fix and improve.

# %%
# alternatively, you can use the following to get the evaluation results in memory

# average scores across all runs
print(response["metrics"])
response
# Out:
# {'rows': [{'inputs.query': [{'role': 'system',
#      'content': 'You are a helpful assistant'},
#     {'createdAt': '2025-04-04T20:48:01Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How is the weather in London ?'}]}],
#    'inputs.response': [{'createdAt': '2025-04-04T20:48:07Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'London'}}]},
#     {'createdAt': '2025-04-04T20:48:08Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Cloudy, 18°C'}}]},
#     {'createdAt': '2025-04-04T20:48:09Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in London is currently cloudy with a temperature of 18°C.'}]}],
#    'inputs.tool_definitions': [{'name': 'convert_temperature',
#      'description': 'Converts temperature from Celsius to Fahrenheit.',
#      'parameters': {'type': 'object',
#       'properties': {'celsius': {'type': 'number',
#         'description': 'Temperature in Celsius.'}}}},
#     {'name': 'send_email',
#      'description': 'Sends an email with the specified subject and body to the recipient.',
#      'parameters': {'type': 'object',
#       'properties': {'recipient': {'type': 'string',
#         'description': 'Email address of the recipient.'},
#        'subject': {'type': 'string', 'description': 'Subject of the email.'},
#        'body': {'type': 'string',
#         'description': 'Body content of the email.'}}}},
#     {'name': 'get_user_info',
#      'description': 'Retrieves user information based on user ID.',
#      'parameters': {'type': 'object',
#       'properties': {'user_id': {'type': 'integer',
#         'description': 'ID of the user.'}}}},
#     {'name': 'opening_hours',
#      'description': 'Fetches the opening hours of a tourist destination in Seattle.',
#      'parameters': {'type': 'object',
#       'properties': {'tourist_destination': {'type': 'string',
#         'description': 'The tourist destination to fetch opening hours for.'}}}},
#     {'name': 'toggle_flag',
#      'description': 'Toggles a boolean flag.',
#      'parameters': {'type': 'object',
#       'properties': {'flag': {'type': 'boolean',
#         'description': 'The flag to toggle.'}}}},
#     {'name': 'longest_word_in_sentences',
#      'description': 'Finds the longest word in each sentence.',
#      'parameters': {'type': 'object',
#       'properties': {'sentences': {'type': 'array',
#         'items': {'type': 'string'},
#         'description': 'A list of sentences.'}}}},
#     {'name': 'merge_dicts',
#      'description': 'Merges two dictionaries.',
#      'parameters': {'type': 'object',
#       'properties': {'dict1': {'type': 'object',
#         'description': 'First dictionary.'},
#        'dict2': {'type': 'object', 'description': 'Second dictionary.'}}}},
#     {'name': 'calculate_sum',
#      'description': 'Calculates the sum of two integers.',
#      'parameters': {'type': 'object',
#       'properties': {'a': {'type': 'integer', 'description': 'First integer.'},
#        'b': {'type': 'integer', 'description': 'Second integer.'}}}},
#     {'name': 'process_records',
#      'description': 'Process a list of records, where each record is a dictionary with string keys and integer values.',
#      'parameters': {'type': 'object',
#       'properties': {'records': {'type': 'array',
#         'items': {'type': 'object'},
#         'description': 'A list containing dictionaries that map strings to integers.'}}}},
#     {'name': 'fetch_current_datetime',
#      'description': 'Get the current time as a JSON string, optionally formatted.',
#      'parameters': {'type': 'object',
#       'properties': {'format': {'type': ['string', 'null'],
#         'description': 'The format in which to return the current time. Defaults to None, which uses a standard format.'}}}},
#     {'name': 'fetch_weather',
#      'description': 'Fetches the weather information for the specified location.',
#      'parameters': {'type': 'object',
#       'properties': {'location': {'type': 'string',
#         'description': 'The location to fetch weather for.'}}}}],
#    'outputs.tool_call_accuracy.tool_call_accuracy': 5.0,
#    'outputs.tool_call_accuracy.tool_call_accuracy_result': 'pass',
#    'outputs.tool_call_accuracy.tool_call_accuracy_threshold': 3,
#    'outputs.tool_call_accuracy.tool_call_accuracy_reason': "Let's think step by step: The user's last query was about the weather in London. The relevant tool from the tool definitions is 'fetch_weather', which fetches weather information for a specified location. The agent correctly called the 'fetch_weather' tool with the parameter 'location' set to 'London', which is grounded in the conversation. The tool call was executed successfully, and the tool returned the weather information without errors. No unnecessary or excessive tool calls were made, and no additional tools were required to address the query. Therefore, the tool call accuracy level is optimal.",
#    'outputs.tool_call_accuracy.details': {'tool_calls_made_by_agent': 1,
#     'correct_tool_calls_made_by_agent': 1,
#     'per_tool_call_details': [{'tool_name': 'fetch_weather',
#       'total_calls_required': 1,
#       'correct_calls_made_by_agent': 1,
#       'correct_tool_percentage': 1.0,
#       'tool_call_errors': 0,
#       'tool_success_result': 'pass'}],
#     'excess_tool_calls': {'total': 0, 'details': []},
#     'missing_tool_calls': {'total': 0, 'details': []}},
#    'outputs.intent_resolution.intent_resolution': 5.0,
#    'outputs.intent_resolution.intent_resolution_result': 'pass',
#    'outputs.intent_resolution.intent_resolution_threshold': 3,
#    'outputs.intent_resolution.intent_resolution_reason': 'User wanted to know the current weather in London. Agent provided accurate and relevant information about the weather and temperature, fully resolving the intent with clarity and precision.',
#    'outputs.task_adherence.task_adherence': 5.0,
#    'outputs.task_adherence.task_adherence_result': 'pass',
#    'outputs.task_adherence.task_adherence_threshold': 3,
#    'outputs.task_adherence.task_adherence_reason': "The assistant correctly identified the task, used the appropriate tool to fetch weather data, and provided a clear and accurate response. The execution fully adhered to the system's constraints and user request.",
#    'line_number': 0},
#   {'inputs.query': [{'role': 'system',
#      'content': 'You are a helpful assistant'},
#     {'createdAt': '2025-04-04T20:48:01Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How is the weather in London ?'}]},
#     {'createdAt': '2025-04-04T20:48:07Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'London'}}]},
#     {'createdAt': '2025-04-04T20:48:08Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Cloudy, 18°C'}}]},
#     {'createdAt': '2025-04-04T20:48:09Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in London is currently cloudy with a temperature of 18°C.'}]},
#     {'createdAt': '2025-04-04T20:48:31Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How about Seattle ?'}]}],
#    'inputs.response': [{'createdAt': '2025-04-04T20:48:33Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'Seattle'}}]},
#     {'createdAt': '2025-04-04T20:48:34Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Rainy, 14°C'}}]},
#     {'createdAt': '2025-04-04T20:48:36Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in Seattle is currently rainy with a temperature of 14°C.'}]}],
#    'inputs.tool_definitions': [{'name': 'convert_temperature',
#      'description': 'Converts temperature from Celsius to Fahrenheit.',
#      'parameters': {'type': 'object',
#       'properties': {'celsius': {'type': 'number',
#         'description': 'Temperature in Celsius.'}}}},
#     {'name': 'send_email',
#      'description': 'Sends an email with the specified subject and body to the recipient.',
#      'parameters': {'type': 'object',
#       'properties': {'recipient': {'type': 'string',
#         'description': 'Email address of the recipient.'},
#        'subject': {'type': 'string', 'description': 'Subject of the email.'},
#        'body': {'type': 'string',
#         'description': 'Body content of the email.'}}}},
#     {'name': 'get_user_info',
#      'description': 'Retrieves user information based on user ID.',
#      'parameters': {'type': 'object',
#       'properties': {'user_id': {'type': 'integer',
#         'description': 'ID of the user.'}}}},
#     {'name': 'opening_hours',
#      'description': 'Fetches the opening hours of a tourist destination in Seattle.',
#      'parameters': {'type': 'object',
#       'properties': {'tourist_destination': {'type': 'string',
#         'description': 'The tourist destination to fetch opening hours for.'}}}},
#     {'name': 'toggle_flag',
#      'description': 'Toggles a boolean flag.',
#      'parameters': {'type': 'object',
#       'properties': {'flag': {'type': 'boolean',
#         'description': 'The flag to toggle.'}}}},
#     {'name': 'longest_word_in_sentences',
#      'description': 'Finds the longest word in each sentence.',
#      'parameters': {'type': 'object',
#       'properties': {'sentences': {'type': 'array',
#         'items': {'type': 'string'},
#         'description': 'A list of sentences.'}}}},
#     {'name': 'merge_dicts',
#      'description': 'Merges two dictionaries.',
#      'parameters': {'type': 'object',
#       'properties': {'dict1': {'type': 'object',
#         'description': 'First dictionary.'},
#        'dict2': {'type': 'object', 'description': 'Second dictionary.'}}}},
#     {'name': 'calculate_sum',
#      'description': 'Calculates the sum of two integers.',
#      'parameters': {'type': 'object',
#       'properties': {'a': {'type': 'integer', 'description': 'First integer.'},
#        'b': {'type': 'integer', 'description': 'Second integer.'}}}},
#     {'name': 'process_records',
#      'description': 'Process a list of records, where each record is a dictionary with string keys and integer values.',
#      'parameters': {'type': 'object',
#       'properties': {'records': {'type': 'array',
#         'items': {'type': 'object'},
#         'description': 'A list containing dictionaries that map strings to integers.'}}}},
#     {'name': 'fetch_current_datetime',
#      'description': 'Get the current time as a JSON string, optionally formatted.',
#      'parameters': {'type': 'object',
#       'properties': {'format': {'type': ['string', 'null'],
#         'description': 'The format in which to return the current time. Defaults to None, which uses a standard format.'}}}},
#     {'name': 'fetch_weather',
#      'description': 'Fetches the weather information for the specified location.',
#      'parameters': {'type': 'object',
#       'properties': {'location': {'type': 'string',
#         'description': 'The location to fetch weather for.'}}}}],
#    'outputs.tool_call_accuracy.tool_call_accuracy': 5.0,
#    'outputs.tool_call_accuracy.tool_call_accuracy_result': 'pass',
#    'outputs.tool_call_accuracy.tool_call_accuracy_threshold': 3,
#    'outputs.tool_call_accuracy.tool_call_accuracy_reason': "Let's think step by step: The user's last query was about the weather in Seattle. The relevant tool to address this query is 'fetch_weather', as it is designed to fetch weather information for a specified location. The agent correctly called the 'fetch_weather' tool with the parameter 'location' set to 'Seattle', which is grounded from the user's query. The tool call was executed successfully, and the tool returned the correct weather information without any errors. No unnecessary duplicate tool calls were made, and no additional tools were required to address the query. Therefore, the tool call was optimal and fully aligned with the user's query.",
#    'outputs.tool_call_accuracy.details': {'tool_calls_made_by_agent': 1,
#     'correct_tool_calls_made_by_agent': 1,
#     'per_tool_call_details': [{'tool_name': 'fetch_weather',
#       'total_calls_required': 1,
#       'correct_calls_made_by_agent': 1,
#       'correct_tool_percentage': 1.0,
#       'tool_call_errors': 0,
#       'tool_success_result': 'pass'}],
#     'excess_tool_calls': {'total': 0, 'details': []},
#     'missing_tool_calls': {'total': 0, 'details': []}},
#    'outputs.intent_resolution.intent_resolution': 5.0,
#    'outputs.intent_resolution.intent_resolution_result': 'pass',
#    'outputs.intent_resolution.intent_resolution_threshold': 3,
#    'outputs.intent_resolution.intent_resolution_reason': 'User wanted the current weather in Seattle after asking about London. Agent provided an accurate and complete response with temperature and conditions, fully resolving the intent without any gaps.',
#    'outputs.task_adherence.task_adherence': 5.0,
#    'outputs.task_adherence.task_adherence_result': 'pass',
#    'outputs.task_adherence.task_adherence_threshold': 3,
#    'outputs.task_adherence.task_adherence_reason': "The assistant correctly identified the user's query, used the appropriate tool to fetch Seattle's weather, and provided a clear and accurate response. No system constraints were violated.",
#    'line_number': 1},
#   {'inputs.query': [{'role': 'system',
#      'content': 'You are a helpful assistant'},
#     {'createdAt': '2025-04-04T20:48:01Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How is the weather in London ?'}]},
#     {'createdAt': '2025-04-04T20:48:07Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'London'}}]},
#     {'createdAt': '2025-04-04T20:48:08Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Cloudy, 18°C'}}]},
#     {'createdAt': '2025-04-04T20:48:09Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in London is currently cloudy with a temperature of 18°C.'}]},
#     {'createdAt': '2025-04-04T20:48:31Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How about Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:48:33Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'Seattle'}}]},
#     {'createdAt': '2025-04-04T20:48:34Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Rainy, 14°C'}}]},
#     {'createdAt': '2025-04-04T20:48:36Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in Seattle is currently rainy with a temperature of 14°C.'}]},
#     {'createdAt': '2025-04-04T20:49:25Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'How are popular places to visit in Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:50:00Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#        'name': 'opening_hours',
#        'arguments': {'tourist_destination': 'Space Needle'}}]},
#     {'createdAt': '2025-04-04T20:50:02Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'opening_hours': '9 AM - 11 PM'}}]},
#     {'createdAt': '2025-04-04T20:50:30Z',
#      'run_id': 'run_xgvcILwpONBHBXRXHfayWpII',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_DnaETwKobebPZnVttxZzQnAM',
#        'name': 'send_email',
#        'arguments': {'recipient': 'your_email@example.com',
#         'subject': 'Seattle and London Weather & Attractions Info',
#         'body': 'Weather in:\n\nLondon: Cloudy, 18°C\nSeattle: Rainy, 14°C\n\nPopular Places to Visit in Seattle:\n1. Space Needle\n2. Pike Place Market\n3. Chihuly Garden and Glass\n4. Seattle Aquarium\n5. Museum of Pop Culture\n6. Seattle Art Museum\n7. Kerry Park\n8. Seattle Great Wheel\n\nOpening Hours:\n- Space Needle: 9 AM - 11 PM'}}]},
#     {'createdAt': '2025-04-04T20:50:33Z',
#      'run_id': 'run_xgvcILwpONBHBXRXHfayWpII',
#      'tool_call_id': 'call_DnaETwKobebPZnVttxZzQnAM',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'message': 'Email successfully sent to your_email@example.com.'}}]}],
#    'inputs.response': [{'createdAt': '2025-04-04T20:49:28Z',
#      'run_id': 'run_Hf1BY0vcUXPM72lYpOCgjm8s',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'Seattle is known for various popular tourist attractions, including:\n\n1. **Space Needle**: An iconic observation tower that offers panoramic views of the city and surrounding mountains.\n2. **Pike Place Market**: A bustling market famous for its fresh produce, gourmet foods, and unique shops, as well as the original Starbucks.\n3. **Chihuly Garden and Glass**: An exhibition showcasing the stunning glass works of artist Dale Chihuly, including a beautiful indoor and outdoor garden.\n4. **Seattle Aquarium**: A family-friendly attraction that features marine life native to the Pacific Northwest.\n5. **Museum of Pop Culture**: A museum dedicated to contemporary popular culture, featuring exhibits on music, science fiction, and more.\n6. **Seattle Art Museum**: A museum that houses an extensive collection of art from various cultures and time periods.\n7. **Kerry Park**: A small park with a renowned viewpoint of the Seattle skyline.\n8. **Seattle Great Wheel**: A large Ferris wheel located on Pier 57 that offers great views of Elliott Bay and the city.\n\nIf you need information about the opening hours for any specific attractions, let me know!'}]}],
#    'inputs.tool_definitions': [{'name': 'convert_temperature',
#      'description': 'Converts temperature from Celsius to Fahrenheit.',
#      'parameters': {'type': 'object',
#       'properties': {'celsius': {'type': 'number',
#         'description': 'Temperature in Celsius.'}}}},
#     {'name': 'send_email',
#      'description': 'Sends an email with the specified subject and body to the recipient.',
#      'parameters': {'type': 'object',
#       'properties': {'recipient': {'type': 'string',
#         'description': 'Email address of the recipient.'},
#        'subject': {'type': 'string', 'description': 'Subject of the email.'},
#        'body': {'type': 'string',
#         'description': 'Body content of the email.'}}}},
#     {'name': 'get_user_info',
#      'description': 'Retrieves user information based on user ID.',
#      'parameters': {'type': 'object',
#       'properties': {'user_id': {'type': 'integer',
#         'description': 'ID of the user.'}}}},
#     {'name': 'opening_hours',
#      'description': 'Fetches the opening hours of a tourist destination in Seattle.',
#      'parameters': {'type': 'object',
#       'properties': {'tourist_destination': {'type': 'string',
#         'description': 'The tourist destination to fetch opening hours for.'}}}},
#     {'name': 'toggle_flag',
#      'description': 'Toggles a boolean flag.',
#      'parameters': {'type': 'object',
#       'properties': {'flag': {'type': 'boolean',
#         'description': 'The flag to toggle.'}}}},
#     {'name': 'longest_word_in_sentences',
#      'description': 'Finds the longest word in each sentence.',
#      'parameters': {'type': 'object',
#       'properties': {'sentences': {'type': 'array',
#         'items': {'type': 'string'},
#         'description': 'A list of sentences.'}}}},
#     {'name': 'merge_dicts',
#      'description': 'Merges two dictionaries.',
#      'parameters': {'type': 'object',
#       'properties': {'dict1': {'type': 'object',
#         'description': 'First dictionary.'},
#        'dict2': {'type': 'object', 'description': 'Second dictionary.'}}}},
#     {'name': 'calculate_sum',
#      'description': 'Calculates the sum of two integers.',
#      'parameters': {'type': 'object',
#       'properties': {'a': {'type': 'integer', 'description': 'First integer.'},
#        'b': {'type': 'integer', 'description': 'Second integer.'}}}},
#     {'name': 'process_records',
#      'description': 'Process a list of records, where each record is a dictionary with string keys and integer values.',
#      'parameters': {'type': 'object',
#       'properties': {'records': {'type': 'array',
#         'items': {'type': 'object'},
#         'description': 'A list containing dictionaries that map strings to integers.'}}}},
#     {'name': 'fetch_current_datetime',
#      'description': 'Get the current time as a JSON string, optionally formatted.',
#      'parameters': {'type': 'object',
#       'properties': {'format': {'type': ['string', 'null'],
#         'description': 'The format in which to return the current time. Defaults to None, which uses a standard format.'}}}},
#     {'name': 'fetch_weather',
#      'description': 'Fetches the weather information for the specified location.',
#      'parameters': {'type': 'object',
#       'properties': {'location': {'type': 'string',
#         'description': 'The location to fetch weather for.'}}}}],
#    'outputs.tool_call_accuracy.tool_call_accuracy': 'not applicable',
#    'outputs.tool_call_accuracy.tool_call_accuracy_result': 'pass',
#    'outputs.tool_call_accuracy.tool_call_accuracy_threshold': 3,
#    'outputs.tool_call_accuracy.tool_call_accuracy_reason': 'No tool calls found in response or provided tool_calls.',
#    'outputs.tool_call_accuracy.details': {},
#    'outputs.intent_resolution.intent_resolution': 5.0,
#    'outputs.intent_resolution.intent_resolution_result': 'pass',
#    'outputs.intent_resolution.intent_resolution_threshold': 3,
#    'outputs.intent_resolution.intent_resolution_reason': 'User wanted information on popular places to visit in Seattle. Agent provided a detailed and accurate list of attractions, fully addressing the intent with thoroughness and relevance.',
#    'outputs.task_adherence.task_adherence': 5.0,
#    'outputs.task_adherence.task_adherence_result': 'pass',
#    'outputs.task_adherence.task_adherence_threshold': 3,
#    'outputs.task_adherence.task_adherence_reason': "The assistant provided a detailed list of popular places to visit in Seattle, fulfilling the user's request without violating any system constraints. No tools were required or expected for this task.",
#    'line_number': 2},
#   {'inputs.query': [{'role': 'system',
#      'content': 'You are a helpful assistant'},
#     {'createdAt': '2025-04-04T20:48:01Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How is the weather in London ?'}]},
#     {'createdAt': '2025-04-04T20:48:07Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'London'}}]},
#     {'createdAt': '2025-04-04T20:48:08Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Cloudy, 18°C'}}]},
#     {'createdAt': '2025-04-04T20:48:09Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in London is currently cloudy with a temperature of 18°C.'}]},
#     {'createdAt': '2025-04-04T20:48:31Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How about Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:48:33Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'Seattle'}}]},
#     {'createdAt': '2025-04-04T20:48:34Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Rainy, 14°C'}}]},
#     {'createdAt': '2025-04-04T20:48:36Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in Seattle is currently rainy with a temperature of 14°C.'}]},
#     {'createdAt': '2025-04-04T20:49:25Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'How are popular places to visit in Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:49:28Z',
#      'run_id': 'run_Hf1BY0vcUXPM72lYpOCgjm8s',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'Seattle is known for various popular tourist attractions, including:\n\n1. **Space Needle**: An iconic observation tower that offers panoramic views of the city and surrounding mountains.\n2. **Pike Place Market**: A bustling market famous for its fresh produce, gourmet foods, and unique shops, as well as the original Starbucks.\n3. **Chihuly Garden and Glass**: An exhibition showcasing the stunning glass works of artist Dale Chihuly, including a beautiful indoor and outdoor garden.\n4. **Seattle Aquarium**: A family-friendly attraction that features marine life native to the Pacific Northwest.\n5. **Museum of Pop Culture**: A museum dedicated to contemporary popular culture, featuring exhibits on music, science fiction, and more.\n6. **Seattle Art Museum**: A museum that houses an extensive collection of art from various cultures and time periods.\n7. **Kerry Park**: A small park with a renowned viewpoint of the Seattle skyline.\n8. **Seattle Great Wheel**: A large Ferris wheel located on Pier 57 that offers great views of Elliott Bay and the city.\n\nIf you need information about the opening hours for any specific attractions, let me know!'}]},
#     {'createdAt': '2025-04-04T20:49:58Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'What are the opening hours of Space Needle ?'}]}],
#    'inputs.response': [{'createdAt': '2025-04-04T20:50:00Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#        'name': 'opening_hours',
#        'arguments': {'tourist_destination': 'Space Needle'}}]},
#     {'createdAt': '2025-04-04T20:50:02Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'opening_hours': '9 AM - 11 PM'}}]},
#     {'createdAt': '2025-04-04T20:50:03Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The Space Needle is open from 9 AM to 11 PM.'}]}],
#    'inputs.tool_definitions': [{'name': 'convert_temperature',
#      'description': 'Converts temperature from Celsius to Fahrenheit.',
#      'parameters': {'type': 'object',
#       'properties': {'celsius': {'type': 'number',
#         'description': 'Temperature in Celsius.'}}}},
#     {'name': 'send_email',
#      'description': 'Sends an email with the specified subject and body to the recipient.',
#      'parameters': {'type': 'object',
#       'properties': {'recipient': {'type': 'string',
#         'description': 'Email address of the recipient.'},
#        'subject': {'type': 'string', 'description': 'Subject of the email.'},
#        'body': {'type': 'string',
#         'description': 'Body content of the email.'}}}},
#     {'name': 'get_user_info',
#      'description': 'Retrieves user information based on user ID.',
#      'parameters': {'type': 'object',
#       'properties': {'user_id': {'type': 'integer',
#         'description': 'ID of the user.'}}}},
#     {'name': 'opening_hours',
#      'description': 'Fetches the opening hours of a tourist destination in Seattle.',
#      'parameters': {'type': 'object',
#       'properties': {'tourist_destination': {'type': 'string',
#         'description': 'The tourist destination to fetch opening hours for.'}}}},
#     {'name': 'toggle_flag',
#      'description': 'Toggles a boolean flag.',
#      'parameters': {'type': 'object',
#       'properties': {'flag': {'type': 'boolean',
#         'description': 'The flag to toggle.'}}}},
#     {'name': 'longest_word_in_sentences',
#      'description': 'Finds the longest word in each sentence.',
#      'parameters': {'type': 'object',
#       'properties': {'sentences': {'type': 'array',
#         'items': {'type': 'string'},
#         'description': 'A list of sentences.'}}}},
#     {'name': 'merge_dicts',
#      'description': 'Merges two dictionaries.',
#      'parameters': {'type': 'object',
#       'properties': {'dict1': {'type': 'object',
#         'description': 'First dictionary.'},
#        'dict2': {'type': 'object', 'description': 'Second dictionary.'}}}},
#     {'name': 'calculate_sum',
#      'description': 'Calculates the sum of two integers.',
#      'parameters': {'type': 'object',
#       'properties': {'a': {'type': 'integer', 'description': 'First integer.'},
#        'b': {'type': 'integer', 'description': 'Second integer.'}}}},
#     {'name': 'process_records',
#      'description': 'Process a list of records, where each record is a dictionary with string keys and integer values.',
#      'parameters': {'type': 'object',
#       'properties': {'records': {'type': 'array',
#         'items': {'type': 'object'},
#         'description': 'A list containing dictionaries that map strings to integers.'}}}},
#     {'name': 'fetch_current_datetime',
#      'description': 'Get the current time as a JSON string, optionally formatted.',
#      'parameters': {'type': 'object',
#       'properties': {'format': {'type': ['string', 'null'],
#         'description': 'The format in which to return the current time. Defaults to None, which uses a standard format.'}}}},
#     {'name': 'fetch_weather',
#      'description': 'Fetches the weather information for the specified location.',
#      'parameters': {'type': 'object',
#       'properties': {'location': {'type': 'string',
#         'description': 'The location to fetch weather for.'}}}}],
#    'outputs.tool_call_accuracy.tool_call_accuracy': 5.0,
#    'outputs.tool_call_accuracy.tool_call_accuracy_result': 'pass',
#    'outputs.tool_call_accuracy.tool_call_accuracy_threshold': 3,
#    'outputs.tool_call_accuracy.tool_call_accuracy_reason': "Let's think step by step: The user's last query is about the opening hours of the Space Needle. From the TOOL DEFINITIONS, the 'opening_hours' tool is the relevant tool to fetch this information. The TOOL CALLS TO BE EVALUATED section shows that the agent correctly called the 'opening_hours' tool with the parameter 'tourist_destination' set to 'Space Needle', which is grounded in the conversation. The tool returned the correct result without any errors. There were no unnecessary duplicate calls or missing calls. Therefore, the tool call was fully relevant, efficient, and successful.",
#    'outputs.tool_call_accuracy.details': {'tool_calls_made_by_agent': 1,
#     'correct_tool_calls_made_by_agent': 1,
#     'per_tool_call_details': [{'tool_name': 'opening_hours',
#       'total_calls_required': 1,
#       'correct_calls_made_by_agent': 1,
#       'correct_tool_percentage': 1.0,
#       'tool_call_errors': 0,
#       'tool_success_result': 'pass'}],
#     'excess_tool_calls': {'total': 0, 'details': []},
#     'missing_tool_calls': {'total': 0, 'details': []}},
#    'outputs.intent_resolution.intent_resolution': 5.0,
#    'outputs.intent_resolution.intent_resolution_result': 'pass',
#    'outputs.intent_resolution.intent_resolution_threshold': 3,
#    'outputs.intent_resolution.intent_resolution_reason': 'User wanted the opening hours of the Space Needle. Agent provided a direct, accurate response with the hours (9 AM to 11 PM), fully resolving the intent without any gaps or issues.',
#    'outputs.task_adherence.task_adherence': 5.0,
#    'outputs.task_adherence.task_adherence_result': 'pass',
#    'outputs.task_adherence.task_adherence_threshold': 3,
#    'outputs.task_adherence.task_adherence_reason': 'The assistant correctly identified the task, used the appropriate tool to fetch the opening hours of the Space Needle, and provided an accurate and concise response. No errors or omissions were observed.',
#    'line_number': 3},
#   {'inputs.query': [{'role': 'system',
#      'content': 'You are a helpful assistant'},
#     {'createdAt': '2025-04-04T20:48:01Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How is the weather in London ?'}]},
#     {'createdAt': '2025-04-04T20:48:07Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'London'}}]},
#     {'createdAt': '2025-04-04T20:48:08Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'tool_call_id': 'call_a2XxwMTijdIclDEdZMjEaePv',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Cloudy, 18°C'}}]},
#     {'createdAt': '2025-04-04T20:48:09Z',
#      'run_id': 'run_l32Z3SXA5g2bxrs6IXbnRolz',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in London is currently cloudy with a temperature of 18°C.'}]},
#     {'createdAt': '2025-04-04T20:48:31Z',
#      'role': 'user',
#      'content': [{'type': 'text', 'text': 'How about Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:48:33Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#        'name': 'fetch_weather',
#        'arguments': {'location': 'Seattle'}}]},
#     {'createdAt': '2025-04-04T20:48:34Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'tool_call_id': 'call_aS0HwOu4vYRFvlEqcrKLmSIN',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'weather': 'Rainy, 14°C'}}]},
#     {'createdAt': '2025-04-04T20:48:36Z',
#      'run_id': 'run_r889lwQqezJlcSkYhD3thurj',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The weather in Seattle is currently rainy with a temperature of 14°C.'}]},
#     {'createdAt': '2025-04-04T20:49:25Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'How are popular places to visit in Seattle ?'}]},
#     {'createdAt': '2025-04-04T20:49:28Z',
#      'run_id': 'run_Hf1BY0vcUXPM72lYpOCgjm8s',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'Seattle is known for various popular tourist attractions, including:\n\n1. **Space Needle**: An iconic observation tower that offers panoramic views of the city and surrounding mountains.\n2. **Pike Place Market**: A bustling market famous for its fresh produce, gourmet foods, and unique shops, as well as the original Starbucks.\n3. **Chihuly Garden and Glass**: An exhibition showcasing the stunning glass works of artist Dale Chihuly, including a beautiful indoor and outdoor garden.\n4. **Seattle Aquarium**: A family-friendly attraction that features marine life native to the Pacific Northwest.\n5. **Museum of Pop Culture**: A museum dedicated to contemporary popular culture, featuring exhibits on music, science fiction, and more.\n6. **Seattle Art Museum**: A museum that houses an extensive collection of art from various cultures and time periods.\n7. **Kerry Park**: A small park with a renowned viewpoint of the Seattle skyline.\n8. **Seattle Great Wheel**: A large Ferris wheel located on Pier 57 that offers great views of Elliott Bay and the city.\n\nIf you need information about the opening hours for any specific attractions, let me know!'}]},
#     {'createdAt': '2025-04-04T20:49:58Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'What are the opening hours of Space Needle ?'}]},
#     {'createdAt': '2025-04-04T20:50:00Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#        'name': 'opening_hours',
#        'arguments': {'tourist_destination': 'Space Needle'}}]},
#     {'createdAt': '2025-04-04T20:50:02Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'tool_call_id': 'call_o5oYob00xO5OFWiNEOyax8Xh',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'opening_hours': '9 AM - 11 PM'}}]},
#     {'createdAt': '2025-04-04T20:50:03Z',
#      'run_id': 'run_HNZQylSFiNSNTC4rDwDDbZOb',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'The Space Needle is open from 9 AM to 11 PM.'}]},
#     {'createdAt': '2025-04-04T20:50:27Z',
#      'role': 'user',
#      'content': [{'type': 'text',
#        'text': 'Can you email me all this info please ?'}]}],
#    'inputs.response': [{'createdAt': '2025-04-04T20:50:30Z',
#      'run_id': 'run_xgvcILwpONBHBXRXHfayWpII',
#      'role': 'assistant',
#      'content': [{'type': 'tool_call',
#        'tool_call_id': 'call_DnaETwKobebPZnVttxZzQnAM',
#        'name': 'send_email',
#        'arguments': {'recipient': 'your_email@example.com',
#         'subject': 'Seattle and London Weather & Attractions Info',
#         'body': 'Weather in:\n\nLondon: Cloudy, 18°C\nSeattle: Rainy, 14°C\n\nPopular Places to Visit in Seattle:\n1. Space Needle\n2. Pike Place Market\n3. Chihuly Garden and Glass\n4. Seattle Aquarium\n5. Museum of Pop Culture\n6. Seattle Art Museum\n7. Kerry Park\n8. Seattle Great Wheel\n\nOpening Hours:\n- Space Needle: 9 AM - 11 PM'}}]},
#     {'createdAt': '2025-04-04T20:50:33Z',
#      'run_id': 'run_xgvcILwpONBHBXRXHfayWpII',
#      'tool_call_id': 'call_DnaETwKobebPZnVttxZzQnAM',
#      'role': 'tool',
#      'content': [{'type': 'tool_result',
#        'tool_result': {'message': 'Email successfully sent to your_email@example.com.'}}]},
#     {'createdAt': '2025-04-04T20:50:34Z',
#      'run_id': 'run_xgvcILwpONBHBXRXHfayWpII',
#      'role': 'assistant',
#      'content': [{'type': 'text',
#        'text': 'I have successfully emailed you the information about the weather in London and Seattle, popular places to visit in Seattle, and the opening hours of the Space Needle. If you need anything else, feel free to ask!'}]}],
#    'inputs.tool_definitions': [{'name': 'convert_temperature',
#      'description': 'Converts temperature from Celsius to Fahrenheit.',
#      'parameters': {'type': 'object',
#       'properties': {'celsius': {'type': 'number',
#         'description': 'Temperature in Celsius.'}}}},
#     {'name': 'send_email',
#      'description': 'Sends an email with the specified subject and body to the recipient.',
#      'parameters': {'type': 'object',
#       'properties': {'recipient': {'type': 'string',
#         'description': 'Email address of the recipient.'},
#        'subject': {'type': 'string', 'description': 'Subject of the email.'},
#        'body': {'type': 'string',
#         'description': 'Body content of the email.'}}}},
#     {'name': 'get_user_info',
#      'description': 'Retrieves user information based on user ID.',
#      'parameters': {'type': 'object',
#       'properties': {'user_id': {'type': 'integer',
#         'description': 'ID of the user.'}}}},
#     {'name': 'opening_hours',
#      'description': 'Fetches the opening hours of a tourist destination in Seattle.',
#      'parameters': {'type': 'object',
#       'properties': {'tourist_destination': {'type': 'string',
#         'description': 'The tourist destination to fetch opening hours for.'}}}},
#     {'name': 'toggle_flag',
#      'description': 'Toggles a boolean flag.',
#      'parameters': {'type': 'object',
#       'properties': {'flag': {'type': 'boolean',
#         'description': 'The flag to toggle.'}}}},
#     {'name': 'longest_word_in_sentences',
#      'description': 'Finds the longest word in each sentence.',
#      'parameters': {'type': 'object',
#       'properties': {'sentences': {'type': 'array',
#         'items': {'type': 'string'},
#         'description': 'A list of sentences.'}}}},
#     {'name': 'merge_dicts',
#      'description': 'Merges two dictionaries.',
#      'parameters': {'type': 'object',
#       'properties': {'dict1': {'type': 'object',
#         'description': 'First dictionary.'},
#        'dict2': {'type': 'object', 'description': 'Second dictionary.'}}}},
#     {'name': 'calculate_sum',
#      'description': 'Calculates the sum of two integers.',
#      'parameters': {'type': 'object',
#       'properties': {'a': {'type': 'integer', 'description': 'First integer.'},
#        'b': {'type': 'integer', 'description': 'Second integer.'}}}},
#     {'name': 'process_records',
#      'description': 'Process a list of records, where each record is a dictionary with string keys and integer values.',
#      'parameters': {'type': 'object',
#       'properties': {'records': {'type': 'array',
#         'items': {'type': 'object'},
#         'description': 'A list containing dictionaries that map strings to integers.'}}}},
#     {'name': 'fetch_current_datetime',
#      'description': 'Get the current time as a JSON string, optionally formatted.',
#      'parameters': {'type': 'object',
#       'properties': {'format': {'type': ['string', 'null'],
#         'description': 'The format in which to return the current time. Defaults to None, which uses a standard format.'}}}},
#     {'name': 'fetch_weather',
#      'description': 'Fetches the weather information for the specified location.',
#      'parameters': {'type': 'object',
#       'properties': {'location': {'type': 'string',
#         'description': 'The location to fetch weather for.'}}}}],
#    'outputs.tool_call_accuracy.tool_call_accuracy': 5.0,
#    'outputs.tool_call_accuracy.tool_call_accuracy_result': 'pass',
#    'outputs.tool_call_accuracy.tool_call_accuracy_threshold': 3,
#    'outputs.tool_call_accuracy.tool_call_accuracy_reason': "Let's think step by step: The user's last query was to email all the information discussed in the conversation. The relevant tool for this task is 'send_email', as per the tool definitions. The agent correctly called the 'send_email' tool with the appropriate parameters extracted from the conversation, including the recipient email, subject, and body content summarizing the weather in London and Seattle, popular places to visit in Seattle, and the opening hours of the Space Needle. The tool call was executed successfully without errors, and no unnecessary or excessive tool calls were made. There were no missing tool calls, as the user's query was fully addressed with the single tool call. Based on this, the tool call accuracy level is optimal.",
#    'outputs.tool_call_accuracy.details': {'tool_calls_made_by_agent': 1,
#     'correct_tool_calls_made_by_agent': 1,
#     'per_tool_call_details': [{'tool_name': 'send_email',
#       'total_calls_required': 1,
#       'correct_calls_made_by_agent': 1,
#       'correct_tool_percentage': 1.0,
#       'tool_call_errors': 0,
#       'tool_success_result': 'pass'}],
#     'excess_tool_calls': {'total': 0, 'details': []},
#     'missing_tool_calls': {'total': 0, 'details': []}},
#    'outputs.intent_resolution.intent_resolution': 3.0,
#    'outputs.intent_resolution.intent_resolution_result': 'pass',
#    'outputs.intent_resolution.intent_resolution_threshold': 3,
#    'outputs.intent_resolution.intent_resolution_reason': 'User wanted the information from the conversation emailed to them. Agent claimed to have sent the email but did not confirm the recipient or provide evidence of the action, leaving the resolution incomplete.',
#    'outputs.task_adherence.task_adherence': 5.0,
#    'outputs.task_adherence.task_adherence_result': 'pass',
#    'outputs.task_adherence.task_adherence_threshold': 3,
#    'outputs.task_adherence.task_adherence_reason': "The assistant correctly identified the task, used the appropriate tool to send the email, and provided confirmation of task completion. The response was clear and fully addressed the user's request.",
#    'line_number': 4}],
#  'metrics': {'tool_call_accuracy.tool_call_accuracy_threshold': 3.0,
#   'intent_resolution.intent_resolution': 4.6,
#   'intent_resolution.intent_resolution_threshold': 3.0,
#   'task_adherence.task_adherence': 5.0,
#   'task_adherence.task_adherence_threshold': 3.0,
#   'tool_call_accuracy.binary_aggregate': 1.0,
#   'intent_resolution.binary_aggregate': 1.0,
#   'task_adherence.binary_aggregate': 1.0},
#  'studio_url': 'https://ai.azure.com/resource/build/evaluation/a7769b5e-2a27-48d3-a06e-b99748e4ada7?wsid=/subscriptions/382e9d43-0c24-4bf6-b807-0a4935bdc6f6/resourceGroups/rg-agashirazi-5194/providers/Microsoft.CognitiveServices/accounts/agashirazi-5194-resource/projects/agashirazi-5194&tid=16b3c013-d300-468d-ac64-7eda0820b6d3'}
